# %%
from mgz import header, body, enums, const
import os
import pandas as pd

type_list = []


with open('/Users/Parikshit_verma/Documents/GitHub/AgeofEmpires2_Voobly/rec.20200210-234038.mgz', 'rb') as data:
    eof = os.fstat(data.fileno()).st_size
    header.parse_stream(data)
    while data.tell() < eof:
        op = body.operation.parse_stream(data)
        if op.type in ('action'):
            print(op)
            print('\n-----------------------------------------')
            print('-----------------------------------------\n')
# Out:
# Container:
#     type = action (total 6)
#     start = 187203
#     op = 1
#     length = 12
#     action = Container:
#         type_int = 119
#         type = queue (total 5)
#         building_id = 7589
#         unit_type = 83
#         number = 4
#     end = 187227
#
# -----------------------------------------
# -----------------------------------------
#
# Container:
#     type = action (total 6)
#     start = 187467
#     op = 1
#     length = 12
#     action = Container:
#         type_int = 119
#         type = queue (total 5)
#         building_id = 7589
#         unit_type = 83
#         number = 4
#     end = 187491
#
# -----------------------------------------
# -----------------------------------------
#
# Container:
#     type = action (total 6)
#     start = 187491
#     op = 1
#     length = 12
#     action = Container:
#         type_int = 119
#         type = queue (total 5)
#         building_id = 7594
#         unit_type = 83
#         number = 1
# ...

# %%
with open('/Users/Parikshit_verma/Documents/GitHub/AgeofEmpires2_Voobly/rec.20200210-234038.mgz', 'rb') as data:
    eof = os.fstat(data.fileno()).st_size
    header.parse_stream(data)
    while data.tell() < eof:
        op = body.operation.parse_stream(data)
        o
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-7ce8c2aade5b> in <module>
#       3     header.parse_stream(data)
#       4     while data.tell() < eof:
# ----> 5         op = body.operation.parse_stream(data)
#       6
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\construct\core.py in parse_stream(self, stream, context, **kw)
#     169         context2.update(kw)
#     170
# --> 171         return self._parse(stream, context2, "(parsing)")
#     172
#     173     def _parse(self, stream, context, path):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\construct\core.py in _parse(self, stream, context, path)
#    2782         try:
#    2783             path += " -> %s" % (self.name)
# -> 2784             return self.subcon._parse(stream, context, path)
#    2785         except ConstructError as e:
#    2786             if "\n" in str(e):
# ...
